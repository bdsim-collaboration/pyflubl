# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T002_RBend_90deg.json",
                                   jsonCoordinateFileName="./T002_RBend_90deg_coordinate.json",
                                   rootFileName="./T002_RBend_90deg001_pyflubl.root",
                                   dumpFileName="./T002_RBend_90deg001_dump",
                                   usrbinFileName=None)
o.plot_projection()
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
