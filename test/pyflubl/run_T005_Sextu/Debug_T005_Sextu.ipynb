# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T005_Sextu.json",
                                   jsonCoordinateFileName="./T005_Sextu_coordinate.json",
                                   rootFileName="./T005_Sextu001_pyflubl.root",
                                   dumpFileName="./T005_Sextu001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zx",eventNumber=slice(0,50))
plt.ylim(-15,15)
