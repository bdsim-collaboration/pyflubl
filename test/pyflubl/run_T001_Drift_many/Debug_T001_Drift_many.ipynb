# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T001_Drift_many.json",
                                   jsonCoordinateFileName="./T001_Drift_many_coordinate.json",
                                   rootFileName="./T001_Drift_many001_pyflubl.root",
                                   dumpFileName="./T001_Drift_many001_dump",
                                   usrbinFileName=None)
o.plot_projection()
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
