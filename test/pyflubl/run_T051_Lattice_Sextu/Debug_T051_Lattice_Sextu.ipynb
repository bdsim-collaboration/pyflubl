# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T051_Lattice_Sextu.json",
                                   jsonCoordinateFileName="./T051_Lattice_Sextu_coordinate.json",
                                   rootFileName="./T051_Lattice_Sextu001_pyflubl.root",
                                   dumpFileName="./T051_Lattice_Sextu001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zx",eventNumber=slice(0,10))
plt.ylim(-15,15)
# Out:
# (-15.0, 15.0)
