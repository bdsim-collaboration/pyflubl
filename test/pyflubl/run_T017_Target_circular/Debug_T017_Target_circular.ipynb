# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...
# ROOT not found

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T017_Target_circular.json",
                                   jsonCoordinateFileName="./T017_Target_circular_coordinate.json",
                                   rootFileName="./T017_Target_circular001_pyflubl.root",
                                   dumpFileName="./T017_Target_circular001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zy",eventNumber=0)
# Out:
# <Axes: xlabel='z/mm', ylabel='y/mm'>
