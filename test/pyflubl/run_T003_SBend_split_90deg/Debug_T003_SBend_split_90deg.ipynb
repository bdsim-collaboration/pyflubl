# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T003_SBend_split_90deg.json",
                                   jsonCoordinateFileName="./T003_SBend_split_90deg_coordinate.json",
                                   rootFileName="./T003_SBend_split_90deg001_pyflubl.root",
                                   dumpFileName="./T003_SBend_split_90deg001_dump",
                                   usrbinFileName=None)
o.plot_projection()
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
