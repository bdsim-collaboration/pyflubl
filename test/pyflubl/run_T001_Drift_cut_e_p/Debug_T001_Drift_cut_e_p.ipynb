# %%
import matplotlib.pyplot as plt
import pyflubl

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T001_Drift_cut_e_p.json",
                                   jsonCoordinateFileName="./T001_Drift_cut_e_p_coordinate.json",
                                   rootFileName="./T001_Drift_cut_e_p001_pyflubl.root",
                                   dumpFileName="./T001_Drift_cut_e_p001_dump",
                                   usrbinFileName=None)

# %%
o.plot_projection(projection="zx")
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>

# %%
o.plot_projection(projection="zy")
# Out:
# <Axes: xlabel='z/mm', ylabel='y/mm'>
