# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T002_RBend_tilt.json",
                                   jsonCoordinateFileName="./T002_RBend_tilt_coordinate.json",
                                   rootFileName="./T002_RBend_tilt001_pyflubl.root",
                                   dumpFileName="./T002_RBend_tilt001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zy")
# Out:
# <Axes: xlabel='z/mm', ylabel='y/mm'>
