# %%
import pyflubl
import matplotlib.pyplot as plt
import numpy as np
import awkward as ak
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./pyflubl.json",
                                   jsonCoordinateFileName="./IPAC_2026_magnetic_coordinate.json",
                                   rootFileName="./IPAC_2026_magnetic001_pyflubl.root",
                                   dumpFileName="./IPAC_2026_magnetic001_dump",
                                   usrbinFileName=None)
o.plot_projection()
plt.ylim(-1000,1000)
plt.savefig("IPAC_2026_magnetic.pdf")
