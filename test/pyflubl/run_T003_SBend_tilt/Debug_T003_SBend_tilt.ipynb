# %%
import matplotlib.pyplot as plt
import pyflubl

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T003_SBend_tilt.json",
                                   jsonCoordinateFileName="./T003_SBend_tilt_coordinate.json",
                                   rootFileName="./T003_SBend_tilt001_pyflubl.root",
                                   dumpFileName="./T003_SBend_tilt001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zy")
# Out:
# <Axes: xlabel='z/mm', ylabel='y/mm'>
