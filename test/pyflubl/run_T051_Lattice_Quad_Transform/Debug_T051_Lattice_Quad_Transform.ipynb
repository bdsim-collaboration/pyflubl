# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T051_Lattice_Quad_Transform.json",
                                   jsonCoordinateFileName="./T051_Lattice_Quad_Transform_coordinate.json",
                                   rootFileName="./T051_Lattice_Quad_Transform001_pyflubl.root",
                                   dumpFileName="./T051_Lattice_Quad_Transform001_dump",
                                   usrbinFileName=None)
o.plot_projection(eventNumber=slice(5,10))
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
