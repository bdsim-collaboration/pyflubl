# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T004_Quad.json",
                                   jsonCoordinateFileName="./T004_Quad_coordinate.json",
                                   rootFileName="./T004_Quad001_pyflubl.root",
                                   dumpFileName="./T004_Quad001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zx",eventNumber=slice(0,50))
plt.ylim(-20,20)
# Out:
# (-20.0, 20.0)
