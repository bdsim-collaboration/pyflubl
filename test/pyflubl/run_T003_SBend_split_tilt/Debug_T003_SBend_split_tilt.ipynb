# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T003_SBend_split_tilt.json",
                                   jsonCoordinateFileName="./T003_SBend_split_tilt_coordinate.json",
                                   rootFileName="./T003_SBend_split_tilt001_pyflubl.root",
                                   dumpFileName="./T003_SBend_split_tilt001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zy")
# Out:
# <Axes: xlabel='z/mm', ylabel='y/mm'>
