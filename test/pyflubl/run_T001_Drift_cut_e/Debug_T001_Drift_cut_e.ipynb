# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T001_Drift_cut_e.json",
                                   jsonCoordinateFileName="./T001_Drift_cut_e_coordinate.json",
                                   rootFileName="./T001_Drift_cut_e001_pyflubl.root",
                                   dumpFileName="./T001_Drift_cut_e001_dump",
                                   usrbinFileName=None)
o.plot_projection()
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
