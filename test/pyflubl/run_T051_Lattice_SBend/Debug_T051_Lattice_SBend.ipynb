# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...
# ROOT not found

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T051_Lattice_SBend.json",
                                   jsonCoordinateFileName="./T051_Lattice_SBend_coordinate.json",
                                   rootFileName="./T051_Lattice_SBend001_pyflubl.root",
                                   dumpFileName="./T051_Lattice_SBend001_dump",
                                   usrbinFileName=None)
o.plot_projection()
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
