# %%
import matplotlib.pyplot as plt
import pyflubl

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T004_Quad_tilt.json",
                                   jsonCoordinateFileName="./T004_Quad_tilt_coordinate.json",
                                   rootFileName="./T004_Quad_tilt001_pyflubl.root",
                                   dumpFileName="./T004_Quad_tilt001_dump",
                                   usrbinFileName=None)

# %%
o.plot_projection(projection="zx",eventNumber=slice(0,50))
plt.ylim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
o.plot_projection(projection="zy",eventNumber=slice(0,50))
plt.ylim(-20,20)
# Out:
# (-20.0, 20.0)
