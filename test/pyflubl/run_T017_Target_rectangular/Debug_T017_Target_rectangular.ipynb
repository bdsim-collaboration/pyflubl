# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T017_Target_rectangular.json",
                                   jsonCoordinateFileName="./T017_Target_rectangular_coordinate.json",
                                   rootFileName="./T017_Target_rectangular001_pyflubl.root",
                                   dumpFileName="./T017_Target_rectangular001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zy",eventNumber=0)
# Out:
# <Axes: xlabel='z/mm', ylabel='y/mm'>
