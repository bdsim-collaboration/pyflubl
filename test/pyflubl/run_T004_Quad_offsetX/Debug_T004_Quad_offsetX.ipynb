# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T004_Quad_offsetX.json",
                                   jsonCoordinateFileName="./T004_Quad_offsetX_coordinate.json",
                                   rootFileName="./T004_Quad_offsetX001_pyflubl.root",
                                   dumpFileName="./T004_Quad_offsetX001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zx",eventNumber=slice(0,50))
plt.ylim(-50,50)
# Out:
# (-50.0, 50.0)
