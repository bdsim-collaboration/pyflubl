# %%
import matplotlib.pyplot as _plt
import pyflubl
import test_T005_SBend

# %%
m = test_T005_SBend.test_T005_sbend()
# Out:
# rho  512.5830895483012
# b_field  6.507432781169975
# ROT-DEFI, 2.0, 0.0, 11.249999999999998, 0.0, 0.0, 0.0, TM000
# ROT-DEFI, 0.0, 0.0, 0.0, -1.9383917874071401, 0.0, 109.74495358404434, TM000
# vacuum region R0005

# %%
d = pyflubl.Analysis.openFile("./run_T005_SBend/T005_SBend001_dump","usrdump")
d.read_event(0)
pyflubl.Analysis.plot_machine_xz(m)
pyflubl.Analysis.plot_usrdump(d)
_plt.xlim(0,2500)
_plt.ylim(-500,500);

# %%
m = test_T005_SBend.test_T005_sbend_split()
# Out:
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 2.25, 0.0, 0.0, 0.0, TM000
# ROT-DEFI, 0.0, 0.0, 0.0, -0.3924972594202579, 0.0, 109.98982233248537, TM000
# vacuum region R0006
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 6.75, 0.0, 0.0, 0.0, TM001
# ROT-DEFI, 0.0, 0.0, 0.0, -1.9600664209783805, 0.0, 129.9076770373566, TM001
# vacuum region R0009
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 11.250000000000002, 0.0, 0.0, 0.0, TM002
# ROT-DEFI, 0.0, 0.0, 0.0, -5.085540158943978, 0.0, 149.64114158451397, TM002
# vacuum region R0012
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 15.75, 0.0, 0.0, 0.0, TM003
# ROT-DEFI, 0.0, 0.0, 0.0, -9.749648888397008, 0.0, 169.06855260298138, TM003
# vacuum region R0015
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 20.250000000000004, 0.0, 0.0, 0.0, TM004
# ROT-DEFI, 0.0, 0.0, 0.0, -15.923636828046853, 0.0, 188.07013364356027, TM004
# vacuum region R0018
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 24.750000000000004, 0.0, 0.0, 0.0, TM005
# ROT-DEFI, 0.0, 0.0, 0.0, -23.569439289186246, 0.0, 206.5287336404686, TM005
# vacuum region R0021
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 29.25, 0.0, 0.0, 0.0, TM006
# ROT-DEFI, 0.0, 0.0, 0.0, -32.63991735715495, 0.0, 224.33054918661801, TM006
# vacuum region R0024
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 33.75000000000001, 0.0, 0.0, 0.0, TM007
# ROT-DEFI, 0.0, 0.0, 0.0, -43.07914851842389, 0.0, 241.36582616946217, TM007
# vacuum region R0027
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 38.25, 0.0, 0.0, 0.0, TM008
# ROT-DEFI, 0.0, 0.0, 0.0, -54.82277144148725, 0.0, 257.5295364415974, TM008
# vacuum region R0030
# rho  2547.1337057128453
# b_field  1.3095504144594927
# ROT-DEFI, 2.0, 0.0, 42.74999999999999, 0.0, 0.0, 0.0, TM009
# ROT-DEFI, 0.0, 0.0, 0.0, -67.79838278587341, 0.0, 272.7220253542169, TM009
# vacuum region R0033

# %%
d = pyflubl.Analysis.openFile("./run_T005_SBend_Split//T005_SBend_Split001_dump","usrdump")
d.read_event(0)
pyflubl.Analysis.plot_machine_xz(m)
pyflubl.Analysis.plot_usrdump(d)
_plt.xlim(0,5000)
_plt.ylim(-1250,250);

# %%
import pyflubl
import test_T110_Ring_RBend
m = test_T110_Ring_RBend.test_T110_ring_rbend()
pyflubl.Analysis.plot_machine_xz(m)
# Out:
# CheckModel
# Number of elements 25
# Number of mid rotations 25
# Number of end rotations 25

# %%
import pyflubl
import test_T111_Ring_SBend
import matplotlib.pyplot as _plt

m = test_T111_Ring_SBend.test_T111_ring_sbend()

d = pyflubl.Analysis.openFile("./run_T111_Ring_SBend/T111_Ring_SBend001_dump","usrdump")
d.read_event(0)

pyflubl.Analysis.plot_machine_xz(m)
pyflubl.Analysis.plot_usrdump(d)

_plt.xlim(-3000,3000)
_plt.ylim(-3000,1000);
# Out:
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0005
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0008
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0011
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0024
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0027
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0030
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0043
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0046
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0049
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0062
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0065
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0068
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0081
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0084
# rho  400.81119539534427
# b_field  8.322122830700616
# vacuum region R0087
