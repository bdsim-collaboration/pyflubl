# %%
import matplotlib.pyplot as _plt
import pyflubl
import test_T005_SBend

# %%
m = test_T005_SBend.test_T005_sbend()

# %%
d = pyflubl.Analysis.openFile("./run_T005_SBend/T005_SBend001_dump","usrdump")
d.read_event(0)
pyflubl.Analysis.plot_machine_xz(m)
pyflubl.Analysis.plot_usrdump(d)
_plt.xlim(0,2500)
_plt.ylim(-500,500);

# %%
d = pyflubl.Analysis.openFile("./run_T005_SBend_Split//T005_SBend_Split001_dump","usrdump")
d.read_event(0)
pyflubl.Analysis.plot_machine_xz(m)
pyflubl.Analysis.plot_usrdump(d)
_plt.xlim(0,5000)
_plt.ylim(-1250,250);

# %% [markdown]
# # Sector bend

# %%
import pyflubl
import test_T111_Ring_SBend
import matplotlib.pyplot as _plt

m = test_T111_Ring_SBend.test_T111_ring_sbend()

# %%
d = pyflubl.Analysis.openFile("./run_T111_Ring_SBend/T111_Ring_SBend001_dump","usrdump")
d.read_event(3)

pyflubl.Analysis.plot_machine_xz(m)
pyflubl.Analysis.plot_usrdump(d)

_plt.xlim(-3500,3500)
_plt.ylim(-6000,500);

#_plt.xlim(0,2000)
#_plt.ylim(-1000,500);

# %% [markdown]
# # Rectangular bend

# %%
import pyflubl
import test_T110_Ring_RBend
import matplotlib.pyplot as _plt

m = test_T110_Ring_RBend.test_T110_ring_rbend()
# Out:
# CheckModel
# Number of elements 75
# Number of mid rotations 75
# Number of end rotations 75

# %%
d = pyflubl.Analysis.openFile("./run_T110_Run_RBend/T110_Ring_RBend001_dump","usrdump")
d.read_event(1)

pyflubl.Analysis.plot_machine_xz(m)
pyflubl.Analysis.plot_usrdump(d)

_plt.xlim(-5000,6000)
_plt.ylim(-10000,1000);

# %% [markdown]
# # Usrbin (local)

# %%
import pyflubl
import test_T204_Usrbin
import matplotlib.pyplot as _plt

m = test_T204_Usrbin.test_T204_Usrbin_element()

# %%
d = pyflubl.Analysis.openFile("./run_T204_Usrbin_element/temp.bnn","usrbin")
bk = pyflubl.Analysis.openBookkeepingFile("T204_Usrbin_element.json")
# Out:
# Read 2 detectors
# Statistics present

# %%
pyflubl.Analysis.plot_usrbin(d,detector_idx=0,projection=1,bookkeeping=bk)
pyflubl.Analysis.plot_usrbin(d,detector_idx=1,projection=1,bookkeeping=bk)
pyflubl.Analysis.plot_machine_xz(m)

# %% [markdown]
# # Usrbin (global)

# %%
import pyflubl
import test_T204_Usrbin
import matplotlib.pyplot as _plt

m = test_T204_Usrbin.test_T204_Usrbin()

# %%
d = pyflubl.Analysis.openFile("./run_T204_Usrbin/temp.bnn","usrbin")
pyflubl.Analysis.plot_usrbin(d,detector_idx=0,projection=1)
pyflubl.Analysis.plot_machine_xz(m)
# Out:
# Read 2 detectors
# Statistics present

# %%
import IPAC_2025
import pyflubl

# %%
m = IPAC_2025.test_IPAC_2025()
# Out:
# MakeFlukaCustomFluka

# %%
pyflubl.Analysis.plot_machine_xz(m)
