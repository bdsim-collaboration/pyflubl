# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T051_Lattice_Drift.json",
                                   jsonCoordinateFileName="./T051_Lattice_Drift_coordinate.json",
                                   rootFileName="./T051_Lattice_Drift001_pyflubl.root",
                                   dumpFileName="./T051_Lattice_Drift001_dump",
                                   usrbinFileName=None)
o.plot_projection()
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
