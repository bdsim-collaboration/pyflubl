# %%
import sys
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./pyflubl.json",
                                   jsonCoordinateFileName="./T270_Source_coordinate.json",
                                   rootFileName="./T270_Source001_pyflubl.root",
                                   dumpFileName="./T270_Source001_dump",
                                   usrbinFileName=None)

# %%
o.plot_projection()
# Out:
# <Axes: xlabel='z/mm', ylabel='x/mm'>
