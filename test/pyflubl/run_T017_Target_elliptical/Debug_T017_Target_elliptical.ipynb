# %%
import matplotlib.pyplot as plt
import pyflubl
# Out:
# initializing ocelot...

# %%
o = pyflubl.Analysis.PyflublOutput(jsonFileName="./T017_Target_elliptical.json",
                                   jsonCoordinateFileName="./T017_Target_elliptical_coordinate.json",
                                   rootFileName="./T017_Target_elliptical001_pyflubl.root",
                                   dumpFileName="./T017_Target_elliptical001_dump",
                                   usrbinFileName=None)
o.plot_projection(projection="zy",eventNumber=0)
# Out:
# <Axes: xlabel='z/mm', ylabel='y/mm'>
